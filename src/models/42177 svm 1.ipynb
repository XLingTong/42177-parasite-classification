# %%
# !pip install tqdm scikit-learn scikit-image matplotlib opencv-python
# Out:
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.12/site-packages (1.7.1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.12/site-packages (0.25.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.5)
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.12/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Collecting numpy>=1.22.0 (from scikit-learn)
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]0m [opencv-python]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.7 requires onnxruntime<2,>=1.15.0, which is not installed.
# autogluon-multimodal 1.4.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.7 requires numpy<=2.0.1, but you have numpy 2.2.6 which is incompatible.
# amazon-sagemaker-sql-magic 0.1.4 requires numpy<2, but you have numpy 2.2.6 which is incompatible.
# autogluon-multimodal 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.55.2 which is incompatible.
# autogluon-timeseries 1.4.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.55.2 which is incompatible.
# gluonts 0.16.2 requires numpy<2.2,>=1.16, but you have numpy 2.2.6 which is incompatible.
# langchain-aws 0.2.19 requires boto3>=1.37.24, but you have boto3 1.37.1 which is incompatible.
# sagemaker 2.245.0 requires numpy==1.26.4, but you have numpy 2.2.6 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.3.1 which is incompatible.
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88

# %%
# =========================================
# Parasite Image Classification - Linear SVM
# Using Preprocessed CLEAN Dataset (Raw Pixels)
# =========================================

import os, cv2, joblib
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score

# ----- 1. Paths and parameters -----
output_dir = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/parasite_output/data/clean"
IMG_SIZE = (48, 48)
MODEL_PATH = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/svm_clean.pkl"
SCALER_PATH = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/scaler_clean.pkl"

# ----- 2. Load images -----
def load_images_full(data_dir):
    X, y, labels = [], [], set()
    subsets = ["train", "val", "test"]
    for subset in subsets:
        subset_path = os.path.join(data_dir, subset)
        if not os.path.isdir(subset_path):
            continue
        class_names = sorted(os.listdir(subset_path))
        for label in class_names:
            folder = os.path.join(subset_path, label)
            if not os.path.isdir(folder):
                continue
            files = [f for f in os.listdir(folder)
                     if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
            for file in tqdm(files, desc=f"{subset}/{label}", ncols=80):
                img_path = os.path.join(folder, file)
                img = cv2.imread(img_path)
                if img is None:
                    continue
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                gray = cv2.resize(gray, IMG_SIZE)
                X.append(gray.flatten())
                y.append(label)
                labels.add(label)
    labels = sorted(list(labels))
    label_to_idx = {lab: i for i, lab in enumerate(labels)}
    y = np.array([label_to_idx[lab] for lab in y])
    return np.array(X), y, labels

# ----- 3. Train Linear SVM -----
def train_svm_linear(X_train, y_train):
    print("Training Linear SVM...")
    model = LinearSVC(C=1.0, loss='squared_hinge', dual=False, max_iter=2000, verbose=1)
    model.fit(X_train, y_train)
    print("Training completed.")
    return model

# ----- 4. Main -----
if __name__ == "__main__":
    X, y, labels = load_images_full(output_dir)
    print(f"\nLoaded {len(X)} images from {len(labels)} classes.")
    print(f"Feature dimension: {X.shape[1]}")

    # Split dataset
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42
    )

    # Standardize
    scaler = StandardScaler().fit(X_train)
    X_train, X_test = scaler.transform(X_train), scaler.transform(X_test)

    # Train model
    model = train_svm_linear(X_train, y_train)

    # Evaluate
    y_pred = model.predict(X_test)
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=labels))
    print("Accuracy:", accuracy_score(y_test, y_pred))

    # Save model and scaler
    joblib.dump(model, MODEL_PATH)
    joblib.dump(scaler, SCALER_PATH)
    print(f"\nModel saved to: {MODEL_PATH}")
    print(f"Scaler saved to: {SCALER_PATH}")
# Out:
# train/babesia: 100%|█████████████████████████| 703/703 [00:06<00:00, 104.59it/s]
# train/leishmania: 100%|█████████████████████| 1620/1620 [00:16<00:00, 98.61it/s]
# train/plasmodium: 100%|██████████████████████| 505/505 [00:05<00:00, 100.70it/s]
# train/toxoplasma1000x: 100%|███████████████| 1759/1759 [00:15<00:00, 111.07it/s]
# train/toxoplasma400x: 100%|████████████████| 2254/2254 [00:17<00:00, 129.86it/s]
# train/trichomonad: 100%|███████████████████| 6080/6080 [01:00<00:00, 100.70it/s]
# train/trypanosome: 100%|███████████████████| 1431/1431 [00:12<00:00, 112.87it/s]
# val/babesia: 100%|███████████████████████████| 234/234 [00:02<00:00, 106.16it/s]
# val/leishmania: 100%|████████████████████████| 540/540 [00:02<00:00, 213.58it/s]
# val/plasmodium: 100%|████████████████████████| 168/168 [00:00<00:00, 221.02it/s]
# val/toxoplasma1000x: 100%|███████████████████| 586/586 [00:02<00:00, 229.71it/s]
# val/toxoplasma400x: 100%|████████████████████| 751/751 [00:03<00:00, 248.06it/s]
# val/trichomonad: 100%|█████████████████████| 2026/2026 [00:09<00:00, 220.38it/s]
# val/trypanosome: 100%|███████████████████████| 477/477 [00:02<00:00, 235.63it/s]
# test/babesia: 100%|██████████████████████████| 236/236 [00:01<00:00, 159.26it/s]
# test/leishmania: 100%|███████████████████████| 541/541 [00:02<00:00, 210.82it/s]
# test/plasmodium: 100%|███████████████████████| 170/170 [00:00<00:00, 215.68it/s]
# test/toxoplasma1000x: 100%|██████████████████| 588/588 [00:02<00:00, 230.73it/s]
# test/toxoplasma400x: 100%|███████████████████| 753/753 [00:03<00:00, 247.36it/s]
# test/trichomonad: 100%|████████████████████| 2028/2028 [00:09<00:00, 220.17it/s]
# test/trypanosome: 100%|██████████████████████| 477/477 [00:02<00:00, 236.58it/s]
# Loaded 23927 images from 7 classes.
# Feature dimension: 2304
# Training Linear SVM...
# [LibLinear]iter  1 act 1.712e+04 pre 1.699e+04 delta 9.119e-01 f 1.914e+04 |g| 7.674e+04 CG  12
# iter  2 act 3.011e+02 pre 2.219e+02 delta 9.119e-01 f 2.023e+03 |g| 1.312e+04 CG  15
# cg reaches trust region boundary
# iter  3 act 3.896e+02 pre 3.206e+02 delta 1.166e+00 f 1.722e+03 |g| 5.479e+03 CG  42
# cg reaches trust region boundary
# iter  4 act 2.383e+02 pre 1.926e+02 delta 1.549e+00 f 1.332e+03 |g| 1.559e+03 CG  40
# cg reaches trust region boundary
# iter  5 act 1.646e+02 pre 1.396e+02 delta 1.919e+00 f 1.094e+03 |g| 1.528e+03 CG  39
# cg reaches trust region boundary
# iter  6 act 1.092e+02 pre 1.131e+02 delta 1.919e+00 f 9.292e+02 |g| 1.128e+03 CG  42
# iter  7 act 4.220e+01 pre 4.121e+01 delta 1.919e+00 f 8.200e+02 |g| 2.772e+03 CG  21
# cg reaches trust region boundary
# iter  8 act 5.551e+01 pre 6.630e+01 delta 1.919e+00 f 7.779e+02 |g| 5.367e+02 CG  40
# cg reaches trust region boundary
# iter  9 act 5.091e+01 pre 8.346e+01 delta 1.390e+00 f 7.223e+02 |g| 1.747e+03 CG  59
# cg reaches trust region boundary
# iter 41 act 9.546e-01 pre 1.063e+00 delta 9.398e-02 f 3.938e+02 |g| 7.710e+01 CG  30
# cg reaches trust region boundary
# iter 42 act 8.909e-01 pre 9.604e-01 delta 9.398e-02 f 3.929e+02 |g| 1.274e+02 CG  28
# cg reaches trust region boundary
# iter 43 act 8.116e-01 pre 9.604e-01 delta 9.398e-02 f 3.920e+02 |g| 1.151e+02 CG  30
# cg reaches trust region boundary
# iter 44 act 7.064e-01 pre 1.008e+00 delta 7.350e-02 f 3.912e+02 |g| 9.379e+01 CG  30
# cg reaches trust region boundary
# iter 45 act 8.473e-01 pre 9.281e-01 delta 7.350e-02 f 3.905e+02 |g| 1.228e+02 CG  28
# cg reaches trust region boundary
# iter 46 act 4.868e-01 pre 6.638e-01 delta 5.870e-02 f 3.896e+02 |g| 6.393e+01 CG  24
# cg reaches trust region boundary
# iter 47 act 5.984e-01 pre 6.617e-01 delta 5.870e-02 f 3.891e+02 |g| 6.847e+01 CG  25
# cg reaches trust region boundary
# iter 48 act 3.721e-01 pre 5.006e-01 delta 4.716e-02 f 3.885e+02 |g| 5.238e+01 CG  22
# cg reaches trust region boundary
# iter 49 act 4.475e-01 pre 4.981e-01 delta 4.716e-02 f 3.882e+02 |g| 6.890e+01 CG  22
# cg reaches trust region boundary
# iter 50 act 3.097e-01 pre 4.060e-01 delta 4.716e-02 f 3.877e+02 |g| 1.289e+02 CG  21
# cg reaches trust region boundary
# iter 51 act 4.110e-01 pre 4.697e-01 delta 4.716e-02 f 3.874e+02 |g| 4.253e+01 CG  22
# cg reaches trust region boundary
# iter 52 act 2.997e-01 pre 4.147e-01 delta 3.749e-02 f 3.870e+02 |g| 6.914e+01 CG  22
# cg reaches trust region boundary
# iter 53 act 3.610e-01 pre 4.039e-01 delta 3.749e-02 f 3.867e+02 |g| 1.393e+02 CG  22
# cg reaches trust region boundary
# iter 54 act 3.029e-01 pre 3.068e-01 delta 3.810e-02 f 3.863e+02 |g| 8.298e+01 CG  21
# cg reaches trust region boundary
# iter 55 act 2.505e-01 pre 3.090e-01 delta 3.810e-02 f 3.860e+02 |g| 3.012e+01 CG  21
# cg reaches trust region boundary
# iter 56 act 3.469e-01 pre 3.509e-01 delta 3.966e-02 f 3.858e+02 |g| 4.157e+01 CG  22
# cg reaches trust region boundary
# iter 57 act 2.852e-01 pre 2.953e-01 delta 3.966e-02 f 3.854e+02 |g| 6.276e+01 CG  22
# cg reaches trust region boundary
# iter 58 act 3.373e-01 pre 3.418e-01 delta 4.162e-02 f 3.851e+02 |g| 3.503e+01 CG  22
# cg reaches trust region boundary
# iter 59 act 3.070e-01 pre 3.192e-01 delta 4.162e-02 f 3.848e+02 |g| 4.465e+01 CG  22
# cg reaches trust region boundary
# iter 60 act 3.254e-01 pre 3.318e-01 delta 4.162e-02 f 3.845e+02 |g| 3.600e+01 CG  22
# cg reaches trust region boundary
# iter 61 act 3.267e-01 pre 3.382e-01 delta 4.181e-02 f 3.842e+02 |g| 7.275e+01 CG  24
# cg reaches trust region boundary
# iter 62 act 3.140e-01 pre 3.204e-01 delta 4.181e-02 f 3.839e+02 |g| 4.168e+01 CG  24
# cg reaches trust region boundary
# iter 63 act 3.283e-01 pre 3.398e-01 delta 4.223e-02 f 3.835e+02 |g| 2.906e+02 CG  24
# cg reaches trust region boundary
# iter 64 act 3.062e-01 pre 3.198e-01 delta 4.223e-02 f 3.832e+02 |g| 3.427e+01 CG  23
# iter 65 act 4.631e-02 pre 4.611e-02 delta 4.223e-02 f 3.829e+02 |g| 3.395e+02 CG   3
# cg reaches trust region boundary
# iter 66 act 2.770e-01 pre 2.885e-01 delta 4.223e-02 f 3.829e+02 |g| 3.301e+01 CG  22
# cg reaches trust region boundary
# iter 67 act 3.159e-01 pre 3.337e-01 delta 4.226e-02 f 3.826e+02 |g| 3.992e+01 CG  23
# cg reaches trust region boundary
# iter 68 act 3.019e-01 pre 3.144e-01 delta 4.226e-02 f 3.823e+02 |g| 4.983e+01 CG  24
# cg reaches trust region boundary
# iter 69 act 3.027e-01 pre 3.228e-01 delta 4.226e-02 f 3.820e+02 |g| 2.073e+02 CG  24
# cg reaches trust region boundary
# iter 70 act 2.931e-01 pre 3.060e-01 delta 4.226e-02 f 3.817e+02 |g| 3.972e+01 CG  24
# cg reaches trust region boundary
# iter 71 act 2.930e-01 pre 3.136e-01 delta 4.226e-02 f 3.814e+02 |g| 4.972e+01 CG  25
# cg reaches trust region boundary
# iter 72 act 3.053e-01 pre 3.204e-01 delta 4.266e-02 f 3.811e+02 |g| 3.760e+01 CG  25
# cg reaches trust region boundary
# iter 73 act 2.723e-01 pre 2.951e-01 delta 4.266e-02 f 3.808e+02 |g| 3.710e+01 CG  25
# cg reaches trust region boundary
# iter 74 act 3.096e-01 pre 3.250e-01 delta 4.392e-02 f 3.805e+02 |g| 3.880e+01 CG  25
# cg reaches trust region boundary
# iter 75 act 2.643e-01 pre 2.887e-01 delta 4.392e-02 f 3.802e+02 |g| 3.845e+01 CG  25
# cg reaches trust region boundary
# iter 76 act 3.184e-01 pre 3.338e-01 delta 4.578e-02 f 3.799e+02 |g| 4.483e+01 CG  25
# cg reaches trust region boundary
# iter 77 act 2.700e-01 pre 2.961e-01 delta 4.578e-02 f 3.796e+02 |g| 3.813e+01 CG  25
# cg reaches trust region boundary
# iter 78 act 3.126e-01 pre 3.263e-01 delta 4.669e-02 f 3.793e+02 |g| 3.741e+01 CG  25
# cg reaches trust region boundary
# iter 79 act 2.613e-01 pre 2.904e-01 delta 4.669e-02 f 3.790e+02 |g| 4.313e+01 CG  26
# cg reaches trust region boundary
# iter 80 act 3.147e-01 pre 3.285e-01 delta 4.669e-02 f 3.788e+02 |g| 4.672e+01 CG  26
# cg reaches trust region boundary
# iter 81 act 2.717e-01 pre 2.976e-01 delta 4.669e-02 f 3.784e+02 |g| 5.416e+01 CG  26
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 145 act 1.968e-02 pre 2.161e-02 delta 1.066e-02 f 3.689e+02 |g| 9.502e+00 CG  25
# cg reaches trust region boundary
# iter 146 act 1.585e-02 pre 1.584e-02 delta 1.075e-02 f 3.689e+02 |g| 7.693e+00 CG  24
# cg reaches trust region boundary
# iter 147 act 1.401e-02 pre 1.635e-02 delta 1.075e-02 f 3.688e+02 |g| 8.377e+00 CG  25
# cg reaches trust region boundary
# iter 148 act 1.354e-02 pre 1.882e-02 delta 8.514e-03 f 3.688e+02 |g| 1.231e+01 CG  25
# cg reaches trust region boundary
# iter 149 act 1.564e-02 pre 1.696e-02 delta 8.514e-03 f 3.688e+02 |g| 8.420e+00 CG  24
# cg reaches trust region boundary
# iter 150 act 1.224e-02 pre 1.225e-02 delta 8.614e-03 f 3.688e+02 |g| 8.120e+00 CG  22
# cg reaches trust region boundary
# iter 151 act 1.198e-02 pre 1.262e-02 delta 8.614e-03 f 3.688e+02 |g| 6.334e+00 CG  22
# cg reaches trust region boundary
# iter 152 act 1.303e-02 pre 1.303e-02 delta 8.655e-03 f 3.688e+02 |g| 1.030e+01 CG  23
# iter 153 act 5.998e-04 pre 5.997e-04 delta 8.655e-03 f 3.688e+02 |g| 6.273e+01 CG   1
# cg reaches trust region boundary
# iter 154 act 1.143e-02 pre 1.218e-02 delta 8.655e-03 f 3.688e+02 |g| 5.889e+00 CG  23
# ...
# cg reaches trust region boundary
# iter 195 act 9.722e-02 pre 1.143e-01 delta 2.270e-02 f 1.165e+02 |g| 2.380e+01 CG  18
# cg reaches trust region boundary
# iter 196 act 1.102e-01 pre 1.245e-01 delta 2.270e-02 f 1.164e+02 |g| 2.774e+01 CG  18
# cg reaches trust region boundary
# iter 197 act 1.026e-01 pre 1.190e-01 delta 2.270e-02 f 1.163e+02 |g| 3.056e+01 CG  18
# cg reaches trust region boundary
# iter 198 act 1.066e-01 pre 1.206e-01 delta 2.270e-02 f 1.162e+02 |g| 2.218e+01 CG  18
# cg reaches trust region boundary
# iter 199 act 9.446e-02 pre 1.125e-01 delta 2.270e-02 f 1.161e+02 |g| 2.592e+01 CG  18
# cg reaches trust region boundary
# iter 200 act 1.066e-01 pre 1.217e-01 delta 2.270e-02 f 1.160e+02 |g| 2.539e+01 CG  19
# cg reaches trust region boundary
# iter 201 act 9.662e-02 pre 1.137e-01 delta 2.270e-02 f 1.159e+02 |g| 2.570e+01 CG  19
# cg reaches trust region boundary
# iter 202 act 1.030e-01 pre 1.188e-01 delta 2.270e-02 f 1.158e+02 |g| 2.411e+01 CG  19
# cg reaches trust region boundary
# iter 203 act 9.609e-02 pre 1.135e-01 delta 2.270e-02 f 1.157e+02 |g| 2.578e+01 CG  19
# cg reaches trust region boundary
# iter 204 act 9.875e-02 pre 1.151e-01 delta 2.270e-02 f 1.156e+02 |g| 2.301e+01 CG  19
# cg reaches trust region boundary
# iter 205 act 9.224e-02 pre 1.135e-01 delta 2.270e-02 f 1.155e+02 |g| 2.623e+01 CG  19
# cg reaches trust region boundary
# iter 206 act 1.008e-01 pre 1.171e-01 delta 2.270e-02 f 1.154e+02 |g| 2.647e+01 CG  19
# cg reaches trust region boundary
# iter 207 act 9.183e-02 pre 1.096e-01 delta 2.270e-02 f 1.153e+02 |g| 2.206e+01 CG  19
# cg reaches trust region boundary
# iter 208 act 9.113e-02 pre 1.094e-01 delta 2.270e-02 f 1.152e+02 |g| 2.664e+01 CG  19
# cg reaches trust region boundary
# iter 209 act 9.402e-02 pre 1.140e-01 delta 2.270e-02 f 1.151e+02 |g| 6.688e+01 CG  20
# cg reaches trust region boundary
# iter 210 act 9.215e-02 pre 1.107e-01 delta 2.270e-02 f 1.150e+02 |g| 3.189e+01 CG  20
# cg reaches trust region boundary
# iter 211 act 8.794e-02 pre 1.063e-01 delta 2.270e-02 f 1.149e+02 |g| 2.345e+01 CG  20
# cg reaches trust region boundary
# iter 212 act 8.945e-02 pre 1.084e-01 delta 2.270e-02 f 1.148e+02 |g| 5.402e+01 CG  20
# cg reaches trust region boundary
# iter 213 act 9.051e-02 pre 1.091e-01 delta 2.270e-02 f 1.148e+02 |g| 3.077e+01 CG  19
# cg reaches trust region boundary
# iter 214 act 8.301e-02 pre 1.037e-01 delta 2.270e-02 f 1.147e+02 |g| 2.675e+01 CG  19
# cg reaches trust region boundary
# iter 215 act 8.793e-02 pre 1.059e-01 delta 2.270e-02 f 1.146e+02 |g| 2.086e+01 CG  19
# cg reaches trust region boundary
# iter 216 act 7.815e-02 pre 1.004e-01 delta 2.270e-02 f 1.145e+02 |g| 3.646e+01 CG  20
# cg reaches trust region boundary
# iter 217 act 8.773e-02 pre 1.040e-01 delta 2.270e-02 f 1.144e+02 |g| 2.518e+01 CG  20
# cg reaches trust region boundary
# iter 218 act 8.833e-02 pre 1.032e-01 delta 2.270e-02 f 1.143e+02 |g| 3.432e+01 CG  20
# cg reaches trust region boundary
# iter 219 act 8.150e-02 pre 9.624e-02 delta 2.270e-02 f 1.142e+02 |g| 2.771e+01 CG  19
# cg reaches trust region boundary
# iter 220 act 7.787e-02 pre 9.600e-02 delta 2.270e-02 f 1.142e+02 |g| 1.818e+01 CG  19
# cg reaches trust region boundary
# iter 221 act 8.413e-02 pre 9.905e-02 delta 2.270e-02 f 1.141e+02 |g| 2.109e+01 CG  21
# cg reaches trust region boundary
# iter 222 act 7.809e-02 pre 9.443e-02 delta 2.270e-02 f 1.140e+02 |g| 3.086e+01 CG  20
# cg reaches trust region boundary
# iter 223 act 8.155e-02 pre 9.529e-02 delta 2.270e-02 f 1.139e+02 |g| 3.557e+01 CG  21
# cg reaches trust region boundary
# iter 224 act 6.827e-02 pre 9.237e-02 delta 1.801e-02 f 1.138e+02 |g| 2.174e+01 CG  21
# cg reaches trust region boundary
# iter 225 act 7.841e-02 pre 8.719e-02 delta 1.801e-02 f 1.138e+02 |g| 2.309e+01 CG  18
# cg reaches trust region boundary
# iter  1 act 4.584e+03 pre 4.557e+03 delta 1.380e-02 f 1.914e+04 |g| 6.642e+05 CG   1
# cg reaches trust region boundary
# iter  2 act 4.750e+02 pre 4.628e+02 delta 1.995e-02 f 1.456e+04 |g| 5.389e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 3.959e+02 pre 4.204e+02 delta 2.006e-02 f 1.408e+04 |g| 5.942e+04 CG   3
# cg reaches trust region boundary
# iter  4 act 3.982e+02 pre 3.949e+02 delta 3.064e-02 f 1.369e+04 |g| 4.801e+04 CG   3
# cg reaches trust region boundary
# iter  5 act 2.674e+02 pre 2.661e+02 delta 4.324e-02 f 1.329e+04 |g| 1.678e+04 CG   3
# cg reaches trust region boundary
# iter  6 act 2.820e+02 pre 2.786e+02 delta 7.340e-02 f 1.302e+04 |g| 1.925e+04 CG   4
# cg reaches trust region boundary
# iter  7 act 3.199e+02 pre 3.190e+02 delta 1.123e-01 f 1.274e+04 |g| 1.129e+04 CG   5
# cg reaches trust region boundary
# iter  8 act 2.680e+02 pre 2.538e+02 delta 1.270e-01 f 1.242e+04 |g| 1.044e+04 CG   6
# cg reaches trust region boundary
# iter  9 act 1.634e+02 pre 1.609e+02 delta 1.301e-01 f 1.215e+04 |g| 8.752e+03 CG   9
# cg reaches trust region boundary
# iter 10 act 1.443e+02 pre 1.460e+02 delta 1.332e-01 f 1.199e+04 |g| 7.672e+03 CG  11
# cg reaches trust region boundary
# iter 11 act 1.240e+02 pre 1.224e+02 delta 1.374e-01 f 1.184e+04 |g| 5.471e+03 CG  11
# cg reaches trust region boundary
# iter 12 act 1.085e+02 pre 1.089e+02 delta 1.403e-01 f 1.172e+04 |g| 3.936e+03 CG  13
# cg reaches trust region boundary
# iter 13 act 1.079e+02 pre 1.070e+02 delta 1.607e-01 f 1.161e+04 |g| 5.213e+03 CG  14
# cg reaches trust region boundary
# iter 14 act 8.828e+01 pre 8.904e+01 delta 1.644e-01 f 1.150e+04 |g| 2.967e+03 CG  14
# cg reaches trust region boundary
# iter 15 act 9.498e+01 pre 9.377e+01 delta 1.673e-01 f 1.141e+04 |g| 4.479e+03 CG  16
# cg reaches trust region boundary
# iter 16 act 8.534e+01 pre 8.732e+01 delta 1.673e-01 f 1.132e+04 |g| 3.437e+03 CG  16
# cg reaches trust region boundary
# iter 17 act 8.923e+01 pre 8.709e+01 delta 1.910e-01 f 1.123e+04 |g| 4.590e+03 CG  17
# cg reaches trust region boundary
# iter 18 act 7.889e+01 pre 8.033e+01 delta 2.090e-01 f 1.114e+04 |g| 3.111e+03 CG  17
# cg reaches trust region boundary
# iter 19 act 9.128e+01 pre 8.915e+01 delta 2.553e-01 f 1.107e+04 |g| 3.602e+03 CG  18
# cg reaches trust region boundary
# iter 20 act 7.685e+01 pre 7.886e+01 delta 2.553e-01 f 1.097e+04 |g| 2.408e+03 CG  19
# cg reaches trust region boundary
# iter 21 act 9.578e+01 pre 9.433e+01 delta 2.745e-01 f 1.090e+04 |g| 4.805e+03 CG  21
# cg reaches trust region boundary
# iter 22 act 8.790e+01 pre 8.777e+01 delta 3.096e-01 f 1.080e+04 |g| 4.348e+03 CG  23
# cg reaches trust region boundary
# iter 23 act 8.415e+01 pre 8.464e+01 delta 3.533e-01 f 1.071e+04 |g| 2.200e+03 CG  24
# cg reaches trust region boundary
# iter 24 act 7.926e+01 pre 7.851e+01 delta 3.740e-01 f 1.063e+04 |g| 1.805e+03 CG  25
# cg reaches trust region boundary
# iter 25 act 8.001e+01 pre 7.999e+01 delta 3.893e-01 f 1.055e+04 |g| 1.870e+03 CG  28
# cg reaches trust region boundary
# iter 26 act 7.491e+01 pre 7.448e+01 delta 4.186e-01 f 1.047e+04 |g| 1.722e+03 CG  31
# cg reaches trust region boundary
# iter 27 act 6.300e+01 pre 6.276e+01 delta 4.253e-01 f 1.040e+04 |g| 1.393e+03 CG  32
# iter 28 act 3.657e+01 pre 3.648e+01 delta 4.253e-01 f 1.033e+04 |g| 5.486e+03 CG  28
# cg reaches trust region boundary
# iter 29 act 3.808e+01 pre 3.796e+01 delta 4.346e-01 f 1.030e+04 |g| 6.113e+02 CG  30
# cg reaches trust region boundary
# iter 30 act 4.926e+01 pre 4.921e+01 delta 4.453e-01 f 1.026e+04 |g| 3.056e+03 CG  39
# cg reaches trust region boundary
# iter 31 act 4.081e+01 pre 4.064e+01 delta 4.557e-01 f 1.021e+04 |g| 3.334e+03 CG  42
# cg reaches trust region boundary
# iter 32 act 3.274e+01 pre 3.275e+01 delta 4.613e-01 f 1.017e+04 |g| 7.420e+02 CG  45
# cg reaches trust region boundary
# iter 33 act 2.552e+01 pre 2.557e+01 delta 4.637e-01 f 1.014e+04 |g| 1.185e+03 CG  53
# cg reaches trust region boundary
# iter 34 act 1.838e+01 pre 1.843e+01 delta 4.637e-01 f 1.011e+04 |g| 7.835e+02 CG  64
# iter 35 act 5.116e+00 pre 5.120e+00 delta 4.637e-01 f 1.009e+04 |g| 1.702e+03 CG  30
# cg reaches trust region boundary
# iter 36 act 7.499e+00 pre 7.442e+00 delta 4.696e-01 f 1.009e+04 |g| 1.676e+02 CG  66
# iter 37 act 2.652e+00 pre 2.659e+00 delta 4.696e-01 f 1.008e+04 |g| 1.062e+03 CG  40
# cg reaches trust region boundary
# iter 38 act 3.332e+00 pre 3.319e+00 delta 4.716e-01 f 1.008e+04 |g| 9.577e+01 CG 117
# iter 39 act 9.689e-02 pre 9.686e-02 delta 4.716e-01 f 1.007e+04 |g| 7.501e+01 CG 128
# iter  1 act 1.354e+04 pre 1.335e+04 delta 8.119e-01 f 1.914e+04 |g| 1.548e+05 CG   8
# iter  2 act 5.246e+02 pre 4.074e+02 delta 8.119e-01 f 5.598e+03 |g| 3.950e+04 CG  10
# iter  3 act 3.058e+02 pre 2.454e+02 delta 8.119e-01 f 5.073e+03 |g| 1.577e+04 CG  12
# cg reaches trust region boundary
# iter  4 act 3.316e+02 pre 2.988e+02 delta 9.199e-01 f 4.767e+03 |g| 1.020e+04 CG  22
# cg reaches trust region boundary
# iter  5 act 2.097e+02 pre 2.078e+02 delta 9.597e-01 f 4.436e+03 |g| 2.836e+03 CG  25
# cg reaches trust region boundary
# iter  6 act 1.718e+02 pre 1.687e+02 delta 9.836e-01 f 4.226e+03 |g| 3.071e+03 CG  32
# cg reaches trust region boundary
# iter  7 act 1.245e+02 pre 1.303e+02 delta 9.836e-01 f 4.054e+03 |g| 3.510e+03 CG  38
# cg reaches trust region boundary
# iter  8 act 1.040e+02 pre 1.047e+02 delta 1.010e+00 f 3.930e+03 |g| 2.369e+03 CG  41
# cg reaches trust region boundary
# iter  9 act 7.611e+01 pre 7.734e+01 delta 1.013e+00 f 3.826e+03 |g| 2.005e+03 CG  47
# cg reaches trust region boundary
# iter 10 act 5.794e+01 pre 6.077e+01 delta 1.013e+00 f 3.749e+03 |g| 2.352e+03 CG  52
# cg reaches trust region boundary
# iter 11 act 4.395e+01 pre 4.612e+01 delta 1.013e+00 f 3.691e+03 |g| 1.072e+03 CG  60
# cg reaches trust region boundary
# iter 12 act 2.931e+01 pre 3.414e+01 delta 1.013e+00 f 3.648e+03 |g| 8.986e+02 CG  67
# cg reaches trust region boundary
# iter 13 act 2.140e+01 pre 2.623e+01 delta 1.013e+00 f 3.618e+03 |g| 7.914e+02 CG  81
# cg reaches trust region boundary
# iter 14 act 1.723e+01 pre 1.771e+01 delta 1.013e+00 f 3.597e+03 |g| 6.862e+02 CG 107
# iter 15 act 6.061e+00 pre 6.053e+00 delta 1.013e+00 f 3.580e+03 |g| 3.364e+02 CG 148
# iter 16 act 5.298e-01 pre 5.289e-01 delta 1.013e+00 f 3.574e+03 |g| 1.318e+02 CG  76
# iter 17 act 2.781e-01 pre 2.793e-01 delta 1.013e+00 f 3.573e+03 |g| 1.907e+01 CG 224
# iter 18 act 4.027e-03 pre 4.029e-03 delta 1.013e+00 f 3.573e+03 |g| 8.759e+00 CG 123
# Training completed.
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#         babesia       0.56      0.71      0.63       235
#      leishmania       0.39      0.25      0.30       540
#      plasmodium       0.33      0.28      0.30       168
# toxoplasma1000x       0.57      0.42      0.48       587
#  toxoplasma400x       0.91      1.00      0.95       752
#     trichomonad       0.69      0.79      0.74      2027
#     trypanosome       0.47      0.42      0.44       477
#
#        accuracy                           0.66      4786
#       macro avg       0.56      0.55      0.55      4786
#    weighted avg       0.64      0.66      0.64      4786
#
# Accuracy: 0.6575428332636858
#
# Model saved to: /mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/svm_clean.pkl
# Scaler saved to: /mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/scaler_clean.pkl

# %%
# =========================================
# Common Evaluation Function
# Equivalent to MATLAB evaluate_model.m
# =========================================

import numpy as np
from sklearn.metrics import confusion_matrix

def evaluate_model(y_true, y_pred, labels):
    """
    Evaluate classification results.

    Parameters
    ----------
    y_true : array-like
        True class labels (list or numpy array)
    y_pred : array-like
        Predicted class labels (list or numpy array)
    labels : list of str
        Ordered list of class names

    Returns
    -------
    results : dict
        {
            "Accuracy": float,
            "Precision": float,
            "Recall": float,
            "F1": float,
            "ConfusionMatrix": np.ndarray,
            "Labels": list
        }
    """

    # Ensure numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Compute confusion matrix with fixed label order
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    # Accuracy
    acc = np.trace(cm) / np.sum(cm)

    # Precision (per class)
    prec = np.diag(cm) / np.maximum(np.sum(cm, axis=1), 1)
    # Recall (per class)
    rec = np.diag(cm) / np.maximum(np.sum(cm, axis=0), 1)
    # F1 (per class)
    f1 = 2 * (prec * rec) / np.maximum(prec + rec, np.finfo(float).eps)

    # Macro averages
    results = {
        "Accuracy": acc,
        "Precision": np.nanmean(prec),
        "Recall": np.nanmean(rec),
        "F1": np.nanmean(f1),
        "ConfusionMatrix": cm,
        "Labels": labels
    }

    # Print summary
    print(f"Accuracy: {acc*100:.2f}%")
    print(f"Precision: {results['Precision']*100:.2f}%  "
          f"Recall: {results['Recall']*100:.2f}%  "
          f"F1: {results['F1']*100:.2f}%")

    return results

# %%
# ======================================================
# Part 2: EVALUATION
# ======================================================
print("\n=== EVALUATION PHASE ===")

# Load saved model and scaler (optional if already in memory)
model = joblib.load(MODEL_PATH)
scaler = joblib.load(SCALER_PATH)

# Use test set from train_test_split above
y_pred = model.predict(X_test)

# Convert integer labels back to names
y_true_names = [labels[i] for i in y_test]
y_pred_names = [labels[i] for i in y_pred]

# Evaluate
print("\n=== Evaluation on CLEAN Dataset ===")
results = evaluate_model(y_true_names, y_pred_names, labels)

print("\nConfusion Matrix:")
print(results["ConfusionMatrix"])
# Out:
# === EVALUATION PHASE ===
#
# === Evaluation on CLEAN Dataset ===
# Accuracy: 65.75%
# Precision: 55.29%  Recall: 55.86%  F1: 54.93%
#
# Confusion Matrix:
# [[ 168    2   14    2    9   35    5]
#  [  30  135   16   38    3  236   82]
#  [  32    3   47    8   22   55    1]
#  [   1    2    9  246   39  219   71]
#  [   0    0    0    1  750    1    0]
#  [  47  162   51   96    1 1601   69]
#  [  24   42    7   41    3  160  200]]

# %%
# =========================================
# Evaluate Linear SVM on All Degraded Datasets
# =========================================

import os, cv2, joblib, numpy as np, pandas as pd
from tqdm import tqdm
from sklearn.metrics import accuracy_score

# ----- Paths -----
DEG_DIR = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/parasite_output/data/degraded"
MODEL_PATH = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/svm_clean.pkl"
SCALER_PATH = "/mnt/custom-file-systems/efs/fs-0a4ab4658fce5fcd7_fsap-036152789f9bb0438/42177/scaler_clean.pkl"
IMG_SIZE = (48, 48)

# ----- Helper: load test set -----
def load_images_for_eval(data_dir):
    X, y, labels = [], [], set()
    subset_path = os.path.join(data_dir, "test")
    if not os.path.isdir(subset_path):
        return None, None, None, None
    class_names = sorted(os.listdir(subset_path))
    for label in class_names:
        folder = os.path.join(subset_path, label)
        if not os.path.isdir(folder):
            continue
        files = [f for f in os.listdir(folder)
                 if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
        for file in files:
            img_path = os.path.join(folder, file)
            img = cv2.imread(img_path)
            if img is None:
                continue
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            gray = cv2.resize(gray, IMG_SIZE)
            X.append(gray.flatten())
            y.append(label)
            labels.add(label)
    if len(X) == 0:
        return None, None, None, None
    labels = sorted(list(labels))
    label_to_idx = {lab: i for i, lab in enumerate(labels)}
    y_idx = np.array([label_to_idx[lab] for lab in y])
    return np.array(X), y_idx, labels, y

# ----- Load model and scaler -----
print("Loading model and scaler...")
model = joblib.load(MODEL_PATH)
scaler = joblib.load(SCALER_PATH)

# ----- Evaluate all degraded folders -----
results_summary = []
degradations = sorted(os.listdir(DEG_DIR))

print("\n=== Evaluating degraded datasets ===\n")
for d in degradations:
    test_path = os.path.join(DEG_DIR, d)
    if not os.path.isdir(test_path):
        continue

    X, y_idx, labels, y_true_names = load_images_for_eval(test_path)
    if X is None:
        continue

    X_scaled = scaler.transform(X)
    y_pred_idx = model.predict(X_scaled)
    y_pred_names = [labels[i] for i in y_pred_idx]

    acc = accuracy_score(y_true_names, y_pred_names)
    results_summary.append({"Degradation": d, "Accuracy": acc * 100})

    print(f"{d:<25s}  Accuracy: {acc*100:.2f}%")

# ----- Display summary table -----
print("\n=== Summary of Model Robustness ===")
df_results = pd.DataFrame(results_summary).sort_values(by="Accuracy", ascending=False)
display(df_results)

# ----- Optional: plot bar chart -----
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.barh(df_results["Degradation"], df_results["Accuracy"], color="#4C72B0")
plt.xlabel("Accuracy (%)")
plt.ylabel("Degradation Type")
plt.title("Model Robustness Across Degradation Types (SVM - Clean Model)")
plt.gca().invert_yaxis()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Loading model and scaler...
#
# === Evaluating degraded datasets ===
#
# gaussian_blur_s1.0         Accuracy: 81.41%
# gaussian_blur_s2.0         Accuracy: 80.03%
# gaussian_noise_s15         Accuracy: 43.13%
# gaussian_noise_s5          Accuracy: 69.46%
# jpeg_q20                   Accuracy: 74.30%
# jpeg_q40                   Accuracy: 77.53%
# jpeg_q60                   Accuracy: 79.57%
# motion_blur_k5             Accuracy: 80.95%
# resolution_x2              Accuracy: 80.97%
# resolution_x4              Accuracy: 78.68%
#
# === Summary of Model Robustness ===
#           Degradation   Accuracy
# 0  gaussian_blur_s1.0  81.410390
# 8       resolution_x2  80.972251
# 7      motion_blur_k5  80.951387
# 1  gaussian_blur_s2.0  80.033382
# 6            jpeg_q60  79.574379
# 9       resolution_x4  78.677238
# 5            jpeg_q40  77.529731
# 4            jpeg_q20  74.295848
# 3   gaussian_noise_s5  69.455456
# 2  gaussian_noise_s15  43.125391
